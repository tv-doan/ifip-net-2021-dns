# %%
import pandas as pd
import numpy as np
import sqlite3
import csv
from datetime import timedelta, date, datetime
import json
from ripe.atlas.cousteau import Measurement

# %%
db = sqlite3.connect("data/ripe-dns-all-probes-with-abuf.db")
df = pd.read_sql_query("SELECT * from data", db)
db.close()

# %%
df[df['target_name'] == '']
# Out:
#             msm_id  prb_id   timestamp      resolver_address address_family  \
# 4         27186736   10092  1600188634  2001:4860:4860::8888              4
# 5         27186736   10092  1600188634         78.90.221.193              4
# 10        27186736   10101  1600188633     2001:b88:1002::10              6
# 13        27186736   10134  1600188636           10.0.12.148              4
# 87        27186736   11108  1600188642     2001:1418:10:2::2              6
# ...            ...     ...         ...                   ...            ...
# 13251908  27187241   10099  1601312239           2a07:a8c0::              6
# 13251952  27187241   28907  1601312234           2a07:a8c0::              6
# 13251964  27187241   32123  1601312234           2a07:a8c0::              6
# 13251974  27187241   35600  1601312239           2a07:a8c0::              6
# 13251978  27187241   51279  1601312234           2a07:a8c0::              6
#
#                rt                                              error  \
# 4                  {"socket": "connect failed Network is unreacha...
# 5                                                  {"timeout": 5000}
# 10                                                 {"timeout": 5000}
# 13                                                 {"timeout": 5000}
# 87                                                 {"timeout": 5000}
# ...           ...                                                ...
# 13251908   26.223                                  {"timeout": 5000}
# 13251952   10.568                                  {"timeout": 5000}
# 13251964   20.429                                  {"timeout": 5000}
# 13251974    9.277                                  {"timeout": 5000}
# 13251978  167.018                                  {"timeout": 5000}
#
#          local_resolver            abuf target_name rcode response_type  \
# 4                  True
# 5                  True
# 10                 True
# 13                 True
# 87                 True
# ...                 ...             ...         ...   ...           ...
# 13251908          False  error, no abuf
# 13251952          False  error, no abuf
# 13251964          False  error, no abuf
# 13251974          False  error, no abuf
# 13251978          False  error, no abuf
#
#          response_address ttl
# 4
# 5
# 10
# 13
# 87
# ...                   ...  ..
# 13251908
# 13251952
# 13251964
# 13251974
# 13251978
#
# [529390 rows x 14 columns]

# %%
df_msm_id_to_target_name = pd.DataFrame(columns=['msm_id', 'target_name_meta'])
msm_ids_location = 'metadata/msm_id_list.csv'
measurements = pd.read_csv(msm_ids_location, header=None)[0].unique()
for msm in measurements:
    measurement = Measurement(id=msm)
    #start_date = measurement.start_time.date()
    #proto = measurement.protocol
    #target = measurement.target
    #print(target)

    descr = measurement.description.split(" ")
    #print(descr[5])
    df_msm_id_to_target_name.loc[len(df_msm_id_to_target_name)] = [msm, descr[5]]

# %%
df = pd.merge(df, df_msm_id_to_target_name, on='msm_id', how='left')

# %%
resolvers_dict = {'185.228.168.168':'CleanBrowsing', '1.1.1.1':'Cloudflare', '8.8.8.8':'Google',
                  '208.67.222.123':'OpenDNS', '185.121.177.177':'OpenNIC', '9.9.9.9':'Quad9', '64.6.64.6':'VeriSign',
                  '77.88.8.8':'Yandex', '156.154.70.1':'Neustar UltraRecursive', '45.90.28.0':'NextDNS',
                  '2a0d:2a00:1::1':'CleanBrowsing', '2606:4700:4700::1111':'Cloudflare',
                  '2001:4860:4860::8888':'Google', '2620:0:ccc::2':'OpenDNS',
                  '2a05:dfc7:5::5353':'OpenNIC', '2620:fe::9':'Quad9', '2620:74:1b::1:1':'VeriSign',
                  '2a02:6b8::feed:ff':'Yandex', '2610:a1:1018::1':'Neustar UltraRecursive',
                     '2a07:a8c0::': 'NextDNS'}

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
df['target_name'] = np.where(df['target_name'].str.endswith('.'), df['target_name'].str[:-1], df['target_name'])
df['target_name'] = df['target_name'].str.lower()
df['address_family'] = df['address_family'].astype(int)
df['rt'] = df['rt'].replace({'' : np.nan}).astype(float)
df['ttl'] = df['ttl'].replace({'' : np.nan}).astype(float)
df['local_resolver'] = df['local_resolver'] == 'True'

# %%
df[df['target_name_meta'] == '']
# Out:
# Empty DataFrame
# Columns: [msm_id, prb_id, timestamp, resolver_address, address_family, rt, error, local_resolver, abuf, target_name, rcode, response_type, response_address, ttl, target_name_meta]
# Index: []

# %%
df[df['target_name'] == ''].target_name_meta.value_counts()
# Out:
# $r.google.com                       30162
# www.t-mobile.com                    23885
# www.youtube.com                     23561
# www.protect-your-privacy-now.com    23052
# www.publicinvasion.com              22897
# www.libero.it                       22813
# www.ifccenter.com                   22791
# www.tohotheater.jp                  22777
# www.uol.com.br                      22774
# www.txxx.com                        22708
# www.chaturbate.com                  22615
# www.microsoft.com                   22578
# www.thedailystar.net                22544
# www.live.com                        22538
# www.apple.com                       22522
# www.cnn.com                         22511
# www.znak.com                        22511
# www.office.com                      22492
# www.fbcdn.net                       22489
# www.wikia.com                       22449
# www.instagram.com                   22273
# www.google.com                      22237
# www.wikipedia.org                   22211
# Name: target_name_meta, dtype: int64

# %%
df
# Out:
#             msm_id  prb_id           timestamp           resolver_address  \
# 0         27186736   10001 2020-09-15 16:50:40  fd00::eadf:70ff:fea3:7a26
# 1         27186736   10001 2020-09-15 16:50:40              192.168.178.1
# 2         27186736   10006 2020-09-15 16:50:37                    8.8.8.8
# 3         27186736   10022 2020-09-15 16:50:44                 10.71.6.12
# 4         27186736   10092 2020-09-15 16:50:34       2001:4860:4860::8888
# ...            ...     ...                 ...                        ...
# 13251991  27187241   54984 2020-09-28 16:57:09                2a07:a8c0::
# 13251992  27187241   55590 2020-09-28 16:57:25                2a07:a8c0::
# 13251993  27187241   55660 2020-09-28 16:57:21                2a07:a8c0::
# 13251994  27187241   55692 2020-09-28 16:57:11                2a07:a8c0::
# 13251995  27187241   55841 2020-09-28 16:57:15                2a07:a8c0::
#
#           address_family       rt  \
# 0                      6   20.312
# 1                      4   15.416
# 2                      4   29.835
# 3                      4   10.700
# 4                      4      NaN
# ...                  ...      ...
# 13251991               6   27.065
# 13251992               6   36.250
# 13251993               6  222.830
# 13251994               6   14.162
# 13251995               6   22.143
#
#                                                       error local_resolver  \
# 0                                                                     True
# 1                                                                     True
# 2                                                                     True
# 3                                                                     True
# 4         {"socket": "connect failed Network is unreacha...           True
# ...                                                     ...            ...
# 13251991                                                             False
# 13251992                                                             False
# 13251993                                                             False
# 13251994                                                             False
# 13251995                                                             False
#
#                                                        abuf  \
# 0         vFGBgwABAAAAAQAAEGQyZGFlNzhiMTk4NTMxNjUGZ29vZ2...
# 1         ti2BgwABAAAAAQAAEGRmNDgyYjYwY2JkNjA0M2UGZ29vZ2...
# 2         hEKBgwABAAAAAQAAEGZlM2M3YzAxN2RhMzYwZWUGZ29vZ2...
# 3         JK2BgwABAAAAAQAAEDdkZTIzYTQwZjQ0ZjQxMTcGZ29vZ2...
# 4
# ...                                                     ...
# 13251991  BWeAgAABAAAADQAAA3d3dwR6bmFrA2NvbQAAHAABwBUAAg...
# 13251992  BE+AgAABAAAADQAAA3d3dwR6bmFrA2NvbQAAHAABwBUAAg...
# 13251993  WwGAgAABAAAADQAAA3d3dwR6bmFrA2NvbQAAHAABwBUAAg...
# 13251994  ffiAgAABAAAAAgAEA3d3dwR6bmFrA2NvbQAAHAABwBAAAg...
# 13251995  XhOAgAABAAAADQAAA3d3dwR6bmFrA2NvbQAAHAABwBUAAg...
#
#                           target_name     rcode response_type  \
# 0         d2dae78b19853165.google.com  NXDOMAIN
# 1         df482b60cbd6043e.google.com  NXDOMAIN
# 2         fe3c7c017da360ee.google.com  NXDOMAIN
# 3         7de23a40f44f4117.google.com  NXDOMAIN
# 4
# ...                               ...       ...           ...
# 13251991                 www.znak.com   NOERROR
# 13251992                 www.znak.com   NOERROR
# 13251993                 www.znak.com   NOERROR
# 13251994                 www.znak.com   NOERROR
# 13251995                 www.znak.com   NOERROR
#
#          response_address  ttl target_name_meta
# 0                          NaN    $r.google.com
# 1                          NaN    $r.google.com
# 2                          NaN    $r.google.com
# 3                          NaN    $r.google.com
# 4                          NaN    $r.google.com
# ...                   ...  ...              ...
# 13251991                   NaN     www.znak.com
# 13251992                   NaN     www.znak.com
# 13251993                   NaN     www.znak.com
# 13251994                   NaN     www.znak.com
# 13251995                   NaN     www.znak.com
#
# [13251996 rows x 15 columns]

# %%
def get_address_family(ip_addr_tmp):
    if ip_addr_tmp.find(':') > 0:
        return 6
    else:
        return 4

# %%
df['response_af'] = df.apply(lambda row: get_address_family(row.response_address), axis=1)

# %%
df[(df.address_family != df.response_af) & (df.response_address != '')].target_name_meta.unique()
# Out:
# array(['$r.google.com', 'www.microsoft.com', 'www.apple.com',
#        'www.uol.com.br', 'www.libero.it',
#        'www.protect-your-privacy-now.com', 'www.publicinvasion.com',
#        'www.txxx.com', 'www.chaturbate.com', 'www.instagram.com',
#        'www.fbcdn.net', 'www.wikia.com', 'www.cnn.com', 'www.google.com',
#        'www.youtube.com', 'www.t-mobile.com', 'www.thedailystar.net',
#        'www.tohotheater.jp', 'www.ifccenter.com', 'www.live.com',
#        'www.office.com', 'www.wikipedia.org', 'www.znak.com'],
#       dtype=object)

# %%
df[(df.address_family != df.response_af) & (df.response_address != '')].prb_id.nunique()
# Out:
# 1147

# %%
df[(df.address_family != df.response_af) & (df.response_address != '') & (df.address_family == 4)]
# Out:
#             msm_id  prb_id           timestamp resolver_address  \
# 1111746   27186769   10568 2020-09-15 16:50:54      192.168.5.1
# 1111747   27186769   11513 2020-09-15 16:50:42     96.76.225.35
# 1111748   27186769   12014 2020-09-15 16:50:54     192.168.33.1
# 1111750   27186769   12020 2020-09-15 16:50:40   91.121.161.184
# 1111753   27186769   12922 2020-09-15 16:50:41         10.0.2.1
# ...            ...     ...                 ...              ...
# 13106851  27187231   54704 2020-09-28 16:57:19      192.168.0.3
# 13106853  27187231   54879 2020-09-28 16:57:50      192.168.1.1
# 13106854  27187231   55364 2020-09-28 16:57:36          1.1.1.1
# 13106856  27187231   55364 2020-09-28 16:57:36          1.0.0.1
# 13106858  27187231   55401 2020-09-28 16:57:39         10.0.4.1
#
#           address_family       rt error  local_resolver  \
# 1111746                4    0.589                  True
# 1111747                4   13.792                  True
# 1111748                4   56.392                  True
# 1111750                4   31.303                  True
# 1111753                4    0.593                  True
# ...                  ...      ...   ...             ...
# 13106851               4  121.663                  True
# 13106853               4    1.432                  True
# 13106854               4   18.073                  True
# 13106856               4   18.852                  True
# 13106858               4    1.035                  True
#
#                                                        abuf  \
# 1111746   paSBgAABAAgAAAAAA3d3dwltaWNyb3NvZnQDY29tAAAcAA...
# 1111747   iDqBgAABAAUACAAFA3d3dwltaWNyb3NvZnQDY29tAAAcAA...
# 1111748   FZOBgAABAAYAAAAAA3d3dwltaWNyb3NvZnQDY29tAAAcAA...
# 1111750   WO6BgAABAAUAAAAAA3d3dwltaWNyb3NvZnQDY29tAAAcAA...
# 1111753   rByBgAABAAgAAAAAA3d3dwltaWNyb3NvZnQDY29tAAAcAA...
# ...                                                     ...
# 13106851  1AGBgAABAAIAAAAAA3d3dwR6bmFrA2NvbQAAHAABwAwABQ...
# 13106853  +wOBgAABAAIAAAAAA3d3dwR6bmFrA2NvbQAAHAABwAwABQ...
# 13106854  poKBgAABAAIAAAAAA3d3dwR6bmFrA2NvbQAAHAABwAwABQ...
# 13106856  UxKBgAABAAIAAAAAA3d3dwR6bmFrA2NvbQAAHAABwAwABQ...
# 13106858  U9uBgAABAAIAAAAAA3d3dwR6bmFrA2NvbQAAHAABwAwABQ...
#
#                 target_name    rcode response_type  \
# 1111746   www.microsoft.com  NOERROR          AAAA
# 1111747   www.microsoft.com  NOERROR          AAAA
# 1111748   www.microsoft.com  NOERROR          AAAA
# 1111750   www.microsoft.com  NOERROR          AAAA
# 1111753   www.microsoft.com  NOERROR          AAAA
# ...                     ...      ...           ...
# 13106851       www.znak.com  NOERROR          AAAA
# 13106853       www.znak.com  NOERROR          AAAA
# 13106854       www.znak.com  NOERROR          AAAA
# 13106856       www.znak.com  NOERROR          AAAA
# 13106858       www.znak.com  NOERROR          AAAA
#
#                             response_address     ttl   target_name_meta  \
# 1111746          2600:1408:24:488:0:0:0:356e    18.0  www.microsoft.com
# 1111747        2600:1407:f800:488:0:0:0:356e    20.0  www.microsoft.com
# 1111748          2a02:26f0:6b:5b6:0:0:0:356e     4.0  www.microsoft.com
# 1111750        2a02:26f0:1700:493:0:0:0:356e    20.0  www.microsoft.com
# 1111753        2a02:26f0:1200:2a9:0:0:0:356e     7.0  www.microsoft.com
# ...                                      ...     ...                ...
# 13106851  2001:41d0:303:aed2:7a6e:616b:0:138  3600.0       www.znak.com
# 13106853  2001:41d0:303:aed2:7a6e:616b:0:138  3587.0       www.znak.com
# 13106854  2001:41d0:303:aed2:7a6e:616b:0:138  3327.0       www.znak.com
# 13106856  2001:41d0:303:aed2:7a6e:616b:0:138  3326.0       www.znak.com
# 13106858  2001:41d0:303:aed2:7a6e:616b:0:138  3599.0       www.znak.com
#
#           response_af  resolver_af
# 1111746             6            4
# 1111747             6            4
# 1111748             6            4
# 1111750             6            4
# 1111753             6            4
# ...               ...          ...
# 13106851            6            4
# 13106853            6            4
# 13106854            6            4
# 13106856            6            4
# 13106858            6            4
#
# [334999 rows x 17 columns]

# %%
df['resolver_af'] = df.apply(lambda row: get_address_family(row.resolver_address), axis=1)

# %%
df[df.address_family != df.resolver_af]
# Out:
#             msm_id  prb_id           timestamp  \
# 4         27186736   10092 2020-09-15 16:50:34
# 128       27186736   11702 2020-09-15 16:50:32
# 163       27186736   11978 2020-09-15 16:50:39
# 193       27186736   12151 2020-09-15 16:50:40
# 285       27186736   13213 2020-09-15 16:50:35
# ...            ...     ...                 ...
# 13103446  27187231   29359 2020-09-27 16:54:06
# 13103914  27187231   51703 2020-09-27 16:55:25
# 13105620  27187231   29359 2020-09-28 16:54:15
# 13106091  27187231   51703 2020-09-28 16:55:16
# 13106806  27187231   52041 2020-09-28 16:57:38
#
#                                  resolver_address  address_family  rt  \
# 4                            2001:4860:4860::8888               4 NaN
# 128       2a02:1812:2c13:c530:280f:c6ff:fef3:727b               4 NaN
# 163                      2401:4800::123:108:224:6               4 NaN
# 193                          2606:4700:4700::1111               4 NaN
# 285                          2001:4860:4860::8888               4 NaN
# ...                                           ...             ...  ..
# 13103446                                  8.8.8.8               6 NaN
# 13103914                       2001:470:e347:1::1               4 NaN
# 13105620                                  8.8.8.8               6 NaN
# 13106091                       2001:470:e347:1::1               4 NaN
# 13106806   2606:a000:140d:4a4:26f5:a2ff:feeb:d7c4               4 NaN
#
#                                                       error local_resolver  \
# 4         {"socket": "connect failed Network is unreacha...           True
# 128       {"socket": "connect failed Network is unreacha...           True
# 163       {"socket": "connect failed Network is unreacha...           True
# 193       {"socket": "connect failed Network is unreacha...           True
# 285       {"socket": "connect failed Network is unreacha...           True
# ...                                                     ...            ...
# 13103446  {"socket": "connect failed Network is unreacha...           True
# 13103914     {"socket": "connect failed Permission denied"}           True
# 13105620  {"socket": "connect failed Network is unreacha...           True
# 13106091     {"socket": "connect failed Permission denied"}           True
# 13106806     {"socket": "connect failed Permission denied"}           True
#
#          abuf target_name rcode response_type response_address  ttl  \
# 4                                                               NaN
# 128                                                             NaN
# 163                                                             NaN
# 193                                                             NaN
# 285                                                             NaN
# ...       ...         ...   ...           ...              ...  ...
# 13103446                                                        NaN
# 13103914                                                        NaN
# 13105620                                                        NaN
# 13106091                                                        NaN
# 13106806                                                        NaN
#
#          target_name_meta  response_af  resolver_af
# 4           $r.google.com            4            6
# 128         $r.google.com            4            6
# 163         $r.google.com            4            6
# 193         $r.google.com            4            6
# 285         $r.google.com            4            6
# ...                   ...          ...          ...
# 13103446     www.znak.com            4            4
# 13103914     www.znak.com            4            6
# 13105620     www.znak.com            4            4
# 13106091     www.znak.com            4            6
# 13106806     www.znak.com            4            6
#
# [12378 rows x 17 columns]

# %%
df[(df.address_family != df.resolver_af) & (df.local_resolver == False)]
# Out:
#             msm_id  prb_id           timestamp      resolver_address  \
# 470515    27186748   26736 2020-10-04 16:50:59  2606:4700:4700::1111
# 471005    27186748   19835 2020-10-04 16:51:08  2606:4700:4700::1111
# 471530    27186748   26736 2020-10-05 16:50:59  2606:4700:4700::1111
# 473080    27186748   26736 2020-10-06 16:51:01  2606:4700:4700::1111
# 497716    27186749   19835 2020-10-04 16:51:08            2620:fe::9
# 497760    27186749   26736 2020-10-04 16:51:03            2620:fe::9
# 498779    27186749   26736 2020-10-05 16:51:01            2620:fe::9
# 499802    27186749   26736 2020-10-06 16:51:01            2620:fe::9
# 519312    27186750   21566 2020-09-29 16:51:16        2a0d:2a00:1::1
# 523872    27186750   19835 2020-10-04 16:50:47        2a0d:2a00:1::1
# 523963    27186750   26736 2020-10-04 16:50:44        2a0d:2a00:1::1
# 524988    27186750   26736 2020-10-05 16:50:46        2a0d:2a00:1::1
# 526003    27186750   26736 2020-10-06 16:50:45        2a0d:2a00:1::1
# 546027    27186751   21566 2020-09-29 16:51:15       2610:a1:1018::1
# 550591    27186751   19835 2020-10-04 16:50:44       2610:a1:1018::1
# 550682    27186751   26736 2020-10-04 16:50:46       2610:a1:1018::1
# 551704    27186751   26736 2020-10-05 16:50:44       2610:a1:1018::1
# 552718    27186751   26736 2020-10-06 16:50:44       2610:a1:1018::1
# 572746    27186752   21566 2020-09-29 16:51:16       2620:74:1b::1:1
# 577306    27186752   19835 2020-10-04 16:50:44       2620:74:1b::1:1
# 577401    27186752   26736 2020-10-04 16:50:42       2620:74:1b::1:1
# 578419    27186752   26736 2020-10-05 16:50:44       2620:74:1b::1:1
# 579437    27186752   26736 2020-10-06 16:50:44       2620:74:1b::1:1
# 599463    27186753   21566 2020-09-29 16:51:13     2a02:6b8::feed:ff
# 604022    27186753   19835 2020-10-04 16:50:42     2a02:6b8::feed:ff
# 604115    27186753   26736 2020-10-04 16:50:41     2a02:6b8::feed:ff
# 605138    27186753   26736 2020-10-05 16:50:44     2a02:6b8::feed:ff
# 606153    27186753   26736 2020-10-06 16:50:42     2a02:6b8::feed:ff
# 626183    27186754   21566 2020-09-29 16:51:22  2001:4860:4860::8888
# 630735    27186754   19835 2020-10-04 16:50:50  2001:4860:4860::8888
# 630830    27186754   26736 2020-10-04 16:50:50  2001:4860:4860::8888
# 631850    27186754   26736 2020-10-05 16:50:48  2001:4860:4860::8888
# 632869    27186754   26736 2020-10-06 16:50:50  2001:4860:4860::8888
# 652898    27186755   21566 2020-09-29 16:51:19         2620:0:ccc::2
# 657452    27186755   19835 2020-10-04 16:50:49         2620:0:ccc::2
# 657548    27186755   26736 2020-10-04 16:50:47         2620:0:ccc::2
# 658565    27186755   26736 2020-10-05 16:50:48         2620:0:ccc::2
# 659585    27186755   26736 2020-10-06 16:50:50         2620:0:ccc::2
# 679612    27186756   21566 2020-09-29 16:51:18     2a05:dfc7:5::5353
# 684168    27186756   19835 2020-10-04 16:50:45     2a05:dfc7:5::5353
# 684266    27186756   26736 2020-10-04 16:50:48     2a05:dfc7:5::5353
# 685283    27186756   26736 2020-10-05 16:50:48     2a05:dfc7:5::5353
# 686297    27186756   26736 2020-10-06 16:50:46     2a05:dfc7:5::5353
# 706330    27186757   21566 2020-09-29 16:51:20           2a07:a8c0::
# 710881    27186757   19835 2020-10-04 16:50:47           2a07:a8c0::
# 710979    27186757   26736 2020-10-04 16:50:46           2a07:a8c0::
# 711997    27186757   26736 2020-10-05 16:50:46           2a07:a8c0::
# 713016    27186757   26736 2020-10-06 16:50:45           2a07:a8c0::
# 6895819   27186993   14784 2020-09-26 16:56:52       2610:a1:1018::1
# 9203847   27187083   14784 2020-09-26 16:56:49     2a02:6b8::feed:ff
# 12549435  27187210   14784 2020-09-26 16:56:49  2606:4700:4700::1111
# 12636481  27187216   14784 2020-09-26 16:56:49  2001:4860:4860::8888
#
#           address_family       rt  \
# 470515                 4   13.279
# 471005                 4   23.074
# 471530                 4   10.303
# 473080                 4   26.537
# 497716                 4   22.422
# 497760                 4   38.743
# 498779                 4   33.496
# 499802                 4   33.292
# 519312                 4   20.927
# 523872                 4   47.241
# 523963                 4   66.768
# 524988                 4   51.238
# 526003                 4   48.721
# 546027                 4   31.634
# 550591                 4   42.471
# 550682                 4   55.300
# 551704                 4   54.583
# 552718                 4   50.476
# 572746                 4   28.918
# 577306                 4  167.230
# 577401                 4   52.117
# 578419                 4   55.622
# 579437                 4   58.383
# 599463                 4   60.386
# 604022                 4   48.508
# 604115                 4   68.964
# 605138                 4   65.785
# 606153                 4   76.513
# 626183                 4    2.193
# 630735                 4   31.425
# 630830                 4   43.518
# 631850                 4   63.651
# 632869                 4   36.984
# 652898                 4    7.011
# 657452                 4  198.680
# 657548                 4   60.854
# 658565                 4   66.614
# 659585                 4   60.760
# 679612                 4    7.402
# 684168                 4   44.002
# 684266                 4   51.641
# 685283                 4   56.423
# 686297                 4   65.594
# 706330                 4   10.823
# 710881                 4    8.483
# 710979                 4   69.226
# 711997                 4  106.724
# 713016                 4   61.746
# 6895819                4   10.396
# 9203847                4  187.737
# 12549435               4    9.518
# 12636481               4    6.579
#
#                                                       error  local_resolver  \
# 470515    {"socket": "connect failed Network is unreacha...           False
# 471005    {"socket": "connect failed Network is unreacha...           False
# 471530    {"socket": "connect failed Network is unreacha...           False
# 473080    {"socket": "connect failed Network is unreacha...           False
# 497716    {"socket": "connect failed Network is unreacha...           False
# 497760    {"socket": "connect failed Network is unreacha...           False
# 498779    {"socket": "connect failed Network is unreacha...           False
# 499802    {"socket": "connect failed Network is unreacha...           False
# 519312    {"socket": "connect failed Network is unreacha...           False
# 523872    {"socket": "connect failed Network is unreacha...           False
# 523963    {"socket": "connect failed Network is unreacha...           False
# 524988    {"socket": "connect failed Network is unreacha...           False
# 526003    {"socket": "connect failed Network is unreacha...           False
# 546027    {"socket": "connect failed Network is unreacha...           False
# 550591    {"socket": "connect failed Network is unreacha...           False
# 550682    {"socket": "connect failed Network is unreacha...           False
# 551704    {"socket": "connect failed Network is unreacha...           False
# 552718    {"socket": "connect failed Network is unreacha...           False
# 572746    {"socket": "connect failed Network is unreacha...           False
# 577306    {"socket": "connect failed Network is unreacha...           False
# 577401    {"socket": "connect failed Network is unreacha...           False
# 578419    {"socket": "connect failed Network is unreacha...           False
# 579437    {"socket": "connect failed Network is unreacha...           False
# 599463    {"socket": "connect failed Network is unreacha...           False
# 604022    {"socket": "connect failed Network is unreacha...           False
# 604115    {"socket": "connect failed Network is unreacha...           False
# 605138    {"socket": "connect failed Network is unreacha...           False
# 606153    {"socket": "connect failed Network is unreacha...           False
# 626183    {"socket": "connect failed Network is unreacha...           False
# 630735    {"socket": "connect failed Network is unreacha...           False
# 630830    {"socket": "connect failed Network is unreacha...           False
# 631850    {"socket": "connect failed Network is unreacha...           False
# 632869    {"socket": "connect failed Network is unreacha...           False
# 652898    {"socket": "connect failed Network is unreacha...           False
# 657452    {"socket": "connect failed Network is unreacha...           False
# 657548    {"socket": "connect failed Network is unreacha...           False
# 658565    {"socket": "connect failed Network is unreacha...           False
# 659585    {"socket": "connect failed Network is unreacha...           False
# 679612    {"socket": "connect failed Network is unreacha...           False
# 684168    {"socket": "connect failed Network is unreacha...           False
# 684266    {"socket": "connect failed Network is unreacha...           False
# 685283    {"socket": "connect failed Network is unreacha...           False
# 686297    {"socket": "connect failed Network is unreacha...           False
# 706330    {"socket": "connect failed Network is unreacha...           False
# 710881    {"socket": "connect failed Network is unreacha...           False
# 710979    {"socket": "connect failed Network is unreacha...           False
# 711997    {"socket": "connect failed Network is unreacha...           False
# 713016    {"socket": "connect failed Network is unreacha...           False
# 6895819   {"socket": "connect failed Network is unreacha...           False
# 9203847   {"socket": "connect failed Network is unreacha...           False
# 12549435  {"socket": "connect failed Network is unreacha...           False
# 12636481  {"socket": "connect failed Network is unreacha...           False
#
#                     abuf target_name rcode response_type response_address  \
# 470515    error, no abuf
# 471005    error, no abuf
# 471530    error, no abuf
# 473080    error, no abuf
# 497716    error, no abuf
# 497760    error, no abuf
# 498779    error, no abuf
# 499802    error, no abuf
# 519312    error, no abuf
# 523872    error, no abuf
# 523963    error, no abuf
# 524988    error, no abuf
# 526003    error, no abuf
# 546027    error, no abuf
# 550591    error, no abuf
# 550682    error, no abuf
# 551704    error, no abuf
# 552718    error, no abuf
# 572746    error, no abuf
# 577306    error, no abuf
# 577401    error, no abuf
# 578419    error, no abuf
# 579437    error, no abuf
# 599463    error, no abuf
# 604022    error, no abuf
# 604115    error, no abuf
# 605138    error, no abuf
# 606153    error, no abuf
# 626183    error, no abuf
# 630735    error, no abuf
# 630830    error, no abuf
# 631850    error, no abuf
# 632869    error, no abuf
# 652898    error, no abuf
# 657452    error, no abuf
# 657548    error, no abuf
# 658565    error, no abuf
# 659585    error, no abuf
# 679612    error, no abuf
# 684168    error, no abuf
# 684266    error, no abuf
# 685283    error, no abuf
# 686297    error, no abuf
# 706330    error, no abuf
# 710881    error, no abuf
# 710979    error, no abuf
# 711997    error, no abuf
# 713016    error, no abuf
# 6895819   error, no abuf
# 9203847   error, no abuf
# 12549435  error, no abuf
# 12636481  error, no abuf
#
#           ttl   target_name_meta  response_af  resolver_af
# 470515    NaN      $r.google.com            4            6
# 471005    NaN      $r.google.com            4            6
# 471530    NaN      $r.google.com            4            6
# 473080    NaN      $r.google.com            4            6
# 497716    NaN      $r.google.com            4            6
# 497760    NaN      $r.google.com            4            6
# 498779    NaN      $r.google.com            4            6
# 499802    NaN      $r.google.com            4            6
# 519312    NaN      $r.google.com            4            6
# 523872    NaN      $r.google.com            4            6
# 523963    NaN      $r.google.com            4            6
# 524988    NaN      $r.google.com            4            6
# 526003    NaN      $r.google.com            4            6
# 546027    NaN      $r.google.com            4            6
# 550591    NaN      $r.google.com            4            6
# 550682    NaN      $r.google.com            4            6
# 551704    NaN      $r.google.com            4            6
# 552718    NaN      $r.google.com            4            6
# 572746    NaN      $r.google.com            4            6
# 577306    NaN      $r.google.com            4            6
# 577401    NaN      $r.google.com            4            6
# 578419    NaN      $r.google.com            4            6
# 579437    NaN      $r.google.com            4            6
# 599463    NaN      $r.google.com            4            6
# 604022    NaN      $r.google.com            4            6
# 604115    NaN      $r.google.com            4            6
# 605138    NaN      $r.google.com            4            6
# 606153    NaN      $r.google.com            4            6
# 626183    NaN      $r.google.com            4            6
# 630735    NaN      $r.google.com            4            6
# 630830    NaN      $r.google.com            4            6
# 631850    NaN      $r.google.com            4            6
# 632869    NaN      $r.google.com            4            6
# 652898    NaN      $r.google.com            4            6
# 657452    NaN      $r.google.com            4            6
# 657548    NaN      $r.google.com            4            6
# 658565    NaN      $r.google.com            4            6
# 659585    NaN      $r.google.com            4            6
# 679612    NaN      $r.google.com            4            6
# 684168    NaN      $r.google.com            4            6
# 684266    NaN      $r.google.com            4            6
# 685283    NaN      $r.google.com            4            6
# 686297    NaN      $r.google.com            4            6
# 706330    NaN      $r.google.com            4            6
# 710881    NaN      $r.google.com            4            6
# 710979    NaN      $r.google.com            4            6
# 711997    NaN      $r.google.com            4            6
# 713016    NaN      $r.google.com            4            6
# 6895819   NaN      www.wikia.com            4            6
# 9203847   NaN   www.t-mobile.com            4            6
# 12549435  NaN  www.wikipedia.org            4            6
# 12636481  NaN  www.wikipedia.org            4            6

# %%
df[(df.address_family != df.resolver_af) & (df.local_resolver == True) & (df.error == '')]
# Out:
# Empty DataFrame
# Columns: [msm_id, prb_id, timestamp, resolver_address, address_family, rt, error, local_resolver, abuf, target_name, rcode, response_type, response_address, ttl, target_name_meta, response_af, resolver_af]
# Index: []

# %%
df[(df.address_family != df.resolver_af) & (df.local_resolver == False) & (df.error == '')]
# Out:
# Empty DataFrame
# Columns: [msm_id, prb_id, timestamp, resolver_address, address_family, rt, error, local_resolver, abuf, target_name, rcode, response_type, response_address, ttl, target_name_meta, response_af, resolver_af]
# Index: []

# %%
df.dtypes
# Out:
# msm_id                      object
# prb_id                       int64
# timestamp           datetime64[ns]
# resolver_address            object
# address_family               int64
# rt                         float64
# error                       object
# local_resolver              object
# abuf                        object
# target_name                 object
# rcode                       object
# response_type               object
# response_address            object
# ttl                        float64
# target_name_meta            object
# response_af                  int64
# resolver_af                  int64
# dtype: object

# %%
df['local_resolver'] = df['local_resolver'] == 'True'

# %%
df.dtypes
# Out:
# msm_id                      object
# prb_id                       int64
# timestamp           datetime64[ns]
# resolver_address            object
# address_family               int64
# rt                         float64
# error                       object
# local_resolver                bool
# abuf                        object
# target_name                 object
# rcode                       object
# response_type               object
# response_address            object
# ttl                        float64
# target_name_meta            object
# response_af                  int64
# resolver_af                  int64
# dtype: object

# %%
conn = sqlite3.connect('data/dns.db')
df.to_sql('data', con=conn, index=False, if_exists='replace')
conn.close()
